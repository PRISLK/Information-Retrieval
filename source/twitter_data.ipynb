# %% [markdown]
# **Assignment1 - Information Retrieval**

# %% [markdown]
# **209381P - T.P.N. Silva**

# %% [markdown]
# **Preprocess Twitter Feed**

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
pip install Unidecode
# Out:
# Collecting Unidecode
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 3.3MB/s
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.1.1

# %%
# Import libaries

import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords

import pandas as pd
import numpy as np
 # Regular expressions
import re  
import string  
import unidecode
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Load text file
filename_tf = '/content/drive/My Drive/Python/IR/twitter_data.txt'
file_tf = open(filename_tf, 'rt')
text_tf = file_tf.read()
file_tf.close()

# Text file before preprocessing
print(text_tf)
print('=====================================================================================================================================\n')

# Convert to lower case
text_tf = text_tf.lower()

# remove all html tags including <br /> tag
clean = re.compile('<.*?>')
text = re.sub(clean, '', text)

# Remove all URLs
clean = re.compile(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b')
text_tf = re.sub(clean, '', text_tf)

# Strip Non Alpha Numeric characters
#text_tf = re.sub(r'\W+', ' ', text_tf)

# Remove accented string
text_tf = unidecode.unidecode(text_tf)

# remove unicode decimal digit
text_tf = re.sub('\d+', '', text_tf)

# remove leading and ending whitespace
text_tf = text_tf.strip()

# remove punctuation
text_output_tf = text_tf.translate(str.maketrans('', '', string.punctuation))

# split text by white space
text_output_tf = text_output_tf.split()

# text file after preprocessing
print(text_output_tf)

result_textfile_tf = (' '.join(str(word) for word in text_output_tf))
print(result_textfile_tf)
# Out:
# ﻿Reminds me of Liberal Immigration Fraudster Monsef avoiding deportation from Canada. #cdnpoli #LPC #CPCLDRäó_ https://t.co/ZOZOSe1CqQ
# #immigration #integration #canada https://t.co/M5cKGyvV8F
# We want controlled immigration that contributes positively to the UK economy. Same as Australia &amp; Canada. https://t.co/99mYliuOes
# Is the new Manitoba immigration fee a head tax? https://t.co/LsG7C3vLe9
# Canada immigration profit influence modernistic delhi yet abhinav: XKofy https://t.co/becgusY2i6
# Canada Immigration Minister to äóìSubstantially Increase  Immigration Numbers https://t.co/nEFw30MRaa https://t.co/cyI867PZRV
# MíÈme les #USA=pays d'immigration par excellence CONTRíîLE RIGOUREUSEMENT l'immigration et accíÂs íæ la #GreenCARD!äó_ https://t.co/IHpVhW2BaG
# @Shawhelp what changes should be made to Canada's immigration laws due to the influx of immigration and violence?
# Läó»immigration irrí©guliíÂre au Canada dí©cortiquí©e en 5 questions https://t.co/f4utO5A7ZF
# L'immigration irrí©guliíÂre au Canada dí©cortiquí©e en 5 questions - https://t.co/UiBsEZOqas https://t.co/j77dEvjoiX https://t.co/XXDeIG7Dbu
# Will Media ask the Liberals if they actually have a solid plan for Canada _ôˆÂ_ôˆ_?? From my view -- immigration out of Cäó_ https://t.co/YAgwmZ8ECp
# Dan Murray ofŒæImmigration Watch Canada is xenophobic racist fear-mongering liar #racism #canada #cdnpoli #hatecrimeäó_ https://t.co/kwZ3csvYxM
# Le Canada lance une vaste campagne d'immigration pour faire face íæ son besoin de main d'ñuvre https://t.co/kXdfMGTZzN
# Läó»#immigration irrí©guliíÂre au #Canada dí©cortiquí©e en 5Œæquestions https://t.co/s3hu1OKKIG
# @Canadidly I've read the Immigration laws of Canada much stricter than the US
# Canada Immigration Website Traffic Surges And Crashes In Wake Of Trump #fasttraffic,#sitetraffic,#website,#traffic https://t.co/zRlJ26jnkC
# Mr Know-all of Canada Immigration https://t.co/wTQK4QDiKI
# Move to Canada @LadyMadonna___ Oh, immigration rules, you can't... https://t.co/5LIEVHO7A4
# #OnThisDay Annette Toft becomes Canada's 2 millionth immigrant since 1945. Do you know your family's immigration stäó_ https://t.co/UvRuw8eR1b
# .@TheEconomist profiles Canada's open immigration policies &amp; how they contribute to our economic success:äó_ https://t.co/4K84EE8Y63
# Hundreds may lose Canadian citizenship, resident status because of one corrupt immigration consultant https://t.co/x2IfO0EXI2
# Immigration for canada without india: an compassionate handle: deyFy
# "#Jamaican #immigrants #Canada
#
# https://t.co/vcmfYGadR5
#
# #statistics #immigration"
# Mexican visa lift expected to cost Canada $262M over a decade https://t.co/9i72fRhtij
# Are people still moving to #Canada ??? Oh that's right, they have real immigration laws and it'säó_ https://t.co/0C5OBfmxLG
# Here are more details on the Richmond, B.C. Immigration Consultant Sunny Wang who was sentenced to 7 years in... https://t.co/YXH5W53srO
# I added a video to a @YouTube playlist https://t.co/CnEyWN40x3 Funny Talking of Haryanavi Jat with Canada Immigration Girl Agent
# Mexicans Can Now Travel Visa-Free To Canada https://t.co/Ec3XHORO2s https://t.co/RQRr5nebcG
# Läó»immigration irrí©guliíÂre au Canada dí©cortiquí©e en 5Œæquestions https://t.co/DkpuKyWmaK
# @SweetnessShawnB Hes the POS that ramped up immigration for Canada, among other globalist policies.
# Canada lifted visa requirements to Mexico as of Dec 1, 2016. Thoughts? #visa #immigration
# @HuffingtonPost people Keep praising Canada and Canada has way stricter immigration laws then us they willl boot your liberal American ass
# =====================================================================================================================================
#
# ['reminds', 'me', 'of', 'liberal', 'immigration', 'fraudster', 'monsef', 'avoiding', 'deportation', 'from', 'canada', 'cdnpoli', 'lpc', 'cpcldrao', 'immigration', 'integration', 'canada', 'we', 'want', 'controlled', 'immigration', 'that', 'contributes', 'positively', 'to', 'the', 'uk', 'economy', 'same', 'as', 'australia', 'amp', 'canada', 'is', 'the', 'new', 'manitoba', 'immigration', 'fee', 'a', 'head', 'tax', 'canada', 'immigration', 'profit', 'influence', 'modernistic', 'delhi', 'yet', 'abhinav', 'xkofy', 'canada', 'immigration', 'minister', 'to', 'aoisubstantially', 'increase', 'immigration', 'numbers', 'mieme', 'les', 'usapays', 'dimmigration', 'par', 'excellence', 'contriile', 'rigoureusement', 'limmigration', 'et', 'accias', 'iae', 'la', 'greencardao', 'shawhelp', 'what', 'changes', 'should', 'be', 'made', 'to', 'canadas', 'immigration', 'laws', 'due', 'to', 'the', 'influx', 'of', 'immigration', 'and', 'violence', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'questions', 'limmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'questions', 'will', 'media', 'ask', 'the', 'liberals', 'if', 'they', 'actually', 'have', 'a', 'solid', 'plan', 'for', 'canada', 'oao', 'from', 'my', 'view', 'immigration', 'out', 'of', 'cao', 'dan', 'murray', 'ofoeaeimmigration', 'watch', 'canada', 'is', 'xenophobic', 'racist', 'fearmongering', 'liar', 'racism', 'canada', 'cdnpoli', 'hatecrimeao', 'le', 'canada', 'lance', 'une', 'vaste', 'campagne', 'dimmigration', 'pour', 'faire', 'face', 'iae', 'son', 'besoin', 'de', 'main', 'dnuvre', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'oeaequestions', 'canadidly', 'ive', 'read', 'the', 'immigration', 'laws', 'of', 'canada', 'much', 'stricter', 'than', 'the', 'us', 'canada', 'immigration', 'website', 'traffic', 'surges', 'and', 'crashes', 'in', 'wake', 'of', 'trump', 'fasttrafficsitetrafficwebsitetraffic', 'mr', 'knowall', 'of', 'canada', 'immigration', 'move', 'to', 'canada', 'ladymadonna', 'oh', 'immigration', 'rules', 'you', 'cant', 'onthisday', 'annette', 'toft', 'becomes', 'canadas', 'millionth', 'immigrant', 'since', 'do', 'you', 'know', 'your', 'familys', 'immigration', 'stao', 'theeconomist', 'profiles', 'canadas', 'open', 'immigration', 'policies', 'amp', 'how', 'they', 'contribute', 'to', 'our', 'economic', 'successao', 'hundreds', 'may', 'lose', 'canadian', 'citizenship', 'resident', 'status', 'because', 'of', 'one', 'corrupt', 'immigration', 'consultant', 'immigration', 'for', 'canada', 'without', 'india', 'an', 'compassionate', 'handle', 'deyfy', 'jamaican', 'immigrants', 'canada', 'statistics', 'immigration', 'mexican', 'visa', 'lift', 'expected', 'to', 'cost', 'canada', 'm', 'over', 'a', 'decade', 'are', 'people', 'still', 'moving', 'to', 'canada', 'oh', 'thats', 'right', 'they', 'have', 'real', 'immigration', 'laws', 'and', 'itsao', 'here', 'are', 'more', 'details', 'on', 'the', 'richmond', 'bc', 'immigration', 'consultant', 'sunny', 'wang', 'who', 'was', 'sentenced', 'to', 'years', 'in', 'i', 'added', 'a', 'video', 'to', 'a', 'youtube', 'playlist', 'funny', 'talking', 'of', 'haryanavi', 'jat', 'with', 'canada', 'immigration', 'girl', 'agent', 'mexicans', 'can', 'now', 'travel', 'visafree', 'to', 'canada', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'oeaequestions', 'sweetnessshawnb', 'hes', 'the', 'pos', 'that', 'ramped', 'up', 'immigration', 'for', 'canada', 'among', 'other', 'globalist', 'policies', 'canada', 'lifted', 'visa', 'requirements', 'to', 'mexico', 'as', 'of', 'dec', 'thoughts', 'visa', 'immigration', 'huffingtonpost', 'people', 'keep', 'praising', 'canada', 'and', 'canada', 'has', 'way', 'stricter', 'immigration', 'laws', 'then', 'us', 'they', 'willl', 'boot', 'your', 'liberal', 'american', 'ass']
# reminds me of liberal immigration fraudster monsef avoiding deportation from canada cdnpoli lpc cpcldrao immigration integration canada we want controlled immigration that contributes positively to the uk economy same as australia amp canada is the new manitoba immigration fee a head tax canada immigration profit influence modernistic delhi yet abhinav xkofy canada immigration minister to aoisubstantially increase immigration numbers mieme les usapays dimmigration par excellence contriile rigoureusement limmigration et accias iae la greencardao shawhelp what changes should be made to canadas immigration laws due to the influx of immigration and violence laoimmigration irricguliiare au canada diccortiquice en questions limmigration irricguliiare au canada diccortiquice en questions will media ask the liberals if they actually have a solid plan for canada oao from my view immigration out of cao dan murray ofoeaeimmigration watch canada is xenophobic racist fearmongering liar racism canada cdnpoli hatecrimeao le canada lance une vaste campagne dimmigration pour faire face iae son besoin de main dnuvre laoimmigration irricguliiare au canada diccortiquice en oeaequestions canadidly ive read the immigration laws of canada much stricter than the us canada immigration website traffic surges and crashes in wake of trump fasttrafficsitetrafficwebsitetraffic mr knowall of canada immigration move to canada ladymadonna oh immigration rules you cant onthisday annette toft becomes canadas millionth immigrant since do you know your familys immigration stao theeconomist profiles canadas open immigration policies amp how they contribute to our economic successao hundreds may lose canadian citizenship resident status because of one corrupt immigration consultant immigration for canada without india an compassionate handle deyfy jamaican immigrants canada statistics immigration mexican visa lift expected to cost canada m over a decade are people still moving to canada oh thats right they have real immigration laws and itsao here are more details on the richmond bc immigration consultant sunny wang who was sentenced to years in i added a video to a youtube playlist funny talking of haryanavi jat with canada immigration girl agent mexicans can now travel visafree to canada laoimmigration irricguliiare au canada diccortiquice en oeaequestions sweetnessshawnb hes the pos that ramped up immigration for canada among other globalist policies canada lifted visa requirements to mexico as of dec thoughts visa immigration huffingtonpost people keep praising canada and canada has way stricter immigration laws then us they willl boot your liberal american ass

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
tokens = word_tokenize(result_textfile_tf)
result_tf = [i for i in tokens if not i in stop_words]
#Array form
print (result_tf)
#String form
result_textfile_tf2 = (' '.join(str(token) for token in result_tf))
# Result text file after removing stop words
print(result_textfile_tf2)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['reminds', 'liberal', 'immigration', 'fraudster', 'monsef', 'avoiding', 'deportation', 'canada', 'cdnpoli', 'lpc', 'cpcldrao', 'immigration', 'integration', 'canada', 'want', 'controlled', 'immigration', 'contributes', 'positively', 'uk', 'economy', 'australia', 'amp', 'canada', 'new', 'manitoba', 'immigration', 'fee', 'head', 'tax', 'canada', 'immigration', 'profit', 'influence', 'modernistic', 'delhi', 'yet', 'abhinav', 'xkofy', 'canada', 'immigration', 'minister', 'aoisubstantially', 'increase', 'immigration', 'numbers', 'mieme', 'les', 'usapays', 'dimmigration', 'par', 'excellence', 'contriile', 'rigoureusement', 'limmigration', 'et', 'accias', 'iae', 'la', 'greencardao', 'shawhelp', 'changes', 'made', 'canadas', 'immigration', 'laws', 'due', 'influx', 'immigration', 'violence', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'questions', 'limmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'questions', 'media', 'ask', 'liberals', 'actually', 'solid', 'plan', 'canada', 'oao', 'view', 'immigration', 'cao', 'dan', 'murray', 'ofoeaeimmigration', 'watch', 'canada', 'xenophobic', 'racist', 'fearmongering', 'liar', 'racism', 'canada', 'cdnpoli', 'hatecrimeao', 'le', 'canada', 'lance', 'une', 'vaste', 'campagne', 'dimmigration', 'pour', 'faire', 'face', 'iae', 'son', 'besoin', 'de', 'main', 'dnuvre', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'oeaequestions', 'canadidly', 'ive', 'read', 'immigration', 'laws', 'canada', 'much', 'stricter', 'us', 'canada', 'immigration', 'website', 'traffic', 'surges', 'crashes', 'wake', 'trump', 'fasttrafficsitetrafficwebsitetraffic', 'mr', 'knowall', 'canada', 'immigration', 'move', 'canada', 'ladymadonna', 'oh', 'immigration', 'rules', 'cant', 'onthisday', 'annette', 'toft', 'becomes', 'canadas', 'millionth', 'immigrant', 'since', 'know', 'familys', 'immigration', 'stao', 'theeconomist', 'profiles', 'canadas', 'open', 'immigration', 'policies', 'amp', 'contribute', 'economic', 'successao', 'hundreds', 'may', 'lose', 'canadian', 'citizenship', 'resident', 'status', 'one', 'corrupt', 'immigration', 'consultant', 'immigration', 'canada', 'without', 'india', 'compassionate', 'handle', 'deyfy', 'jamaican', 'immigrants', 'canada', 'statistics', 'immigration', 'mexican', 'visa', 'lift', 'expected', 'cost', 'canada', 'decade', 'people', 'still', 'moving', 'canada', 'oh', 'thats', 'right', 'real', 'immigration', 'laws', 'itsao', 'details', 'richmond', 'bc', 'immigration', 'consultant', 'sunny', 'wang', 'sentenced', 'years', 'added', 'video', 'youtube', 'playlist', 'funny', 'talking', 'haryanavi', 'jat', 'canada', 'immigration', 'girl', 'agent', 'mexicans', 'travel', 'visafree', 'canada', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'oeaequestions', 'sweetnessshawnb', 'hes', 'pos', 'ramped', 'immigration', 'canada', 'among', 'globalist', 'policies', 'canada', 'lifted', 'visa', 'requirements', 'mexico', 'dec', 'thoughts', 'visa', 'immigration', 'huffingtonpost', 'people', 'keep', 'praising', 'canada', 'canada', 'way', 'stricter', 'immigration', 'laws', 'us', 'willl', 'boot', 'liberal', 'american', 'ass']
# reminds liberal immigration fraudster monsef avoiding deportation canada cdnpoli lpc cpcldrao immigration integration canada want controlled immigration contributes positively uk economy australia amp canada new manitoba immigration fee head tax canada immigration profit influence modernistic delhi yet abhinav xkofy canada immigration minister aoisubstantially increase immigration numbers mieme les usapays dimmigration par excellence contriile rigoureusement limmigration et accias iae la greencardao shawhelp changes made canadas immigration laws due influx immigration violence laoimmigration irricguliiare au canada diccortiquice en questions limmigration irricguliiare au canada diccortiquice en questions media ask liberals actually solid plan canada oao view immigration cao dan murray ofoeaeimmigration watch canada xenophobic racist fearmongering liar racism canada cdnpoli hatecrimeao le canada lance une vaste campagne dimmigration pour faire face iae son besoin de main dnuvre laoimmigration irricguliiare au canada diccortiquice en oeaequestions canadidly ive read immigration laws canada much stricter us canada immigration website traffic surges crashes wake trump fasttrafficsitetrafficwebsitetraffic mr knowall canada immigration move canada ladymadonna oh immigration rules cant onthisday annette toft becomes canadas millionth immigrant since know familys immigration stao theeconomist profiles canadas open immigration policies amp contribute economic successao hundreds may lose canadian citizenship resident status one corrupt immigration consultant immigration canada without india compassionate handle deyfy jamaican immigrants canada statistics immigration mexican visa lift expected cost canada decade people still moving canada oh thats right real immigration laws itsao details richmond bc immigration consultant sunny wang sentenced years added video youtube playlist funny talking haryanavi jat canada immigration girl agent mexicans travel visafree canada laoimmigration irricguliiare au canada diccortiquice en oeaequestions sweetnessshawnb hes pos ramped immigration canada among globalist policies canada lifted visa requirements mexico dec thoughts visa immigration huffingtonpost people keep praising canada canada way stricter immigration laws us willl boot liberal american ass

# %%
pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading https://files.pythonhosted.org/packages/f1/96/827c132397d0eb5731c1eda05dbfb019ede064ca8c7d0f329160ce0a4acd/pyspellchecker-0.5.5-py2.py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 3.2MB/s
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.5.5

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

# find those words that may be misspelled
misspelled_text_tf = spell.unknown(result_tf)
print("Mispelled count: {}".format(len(misspelled_text_tf)))
print(misspelled_text_tf)

for word in misspelled_text_tf:
    corrected_word = spell.correction(word)
    candidate_words = spell.candidates(word)
    

    # Get the one `most likely` answer
    print('word :' + ' ' + word + '\n' + 'corrected word : ' + corrected_word)
  
    # Get a list of `likely` options
    print('candidate words :')
    print(candidate_words)
# Out:
# Mispelled count: 49
# {'rigoureusement', 'itsao', 'ladymadonna', 'iae', 'abhinav', 'canadidly', 'cdnpoli', 'dimmigration', 'mieme', 'fearmongering', 'accias', 'laoimmigration', 'website', 'dnuvre', 'vaste', 'canadas', 'contriile', 'successao', 'aoisubstantially', 'hatecrimeao', 'jat', 'ofoeaeimmigration', 'theeconomist', 'limmigration', 'oao', 'onthisday', 'stao', 'huffingtonpost', 'lpc', 'irricguliiare', 'willl', 'xkofy', 'deyfy', 'besoin', 'oeaequestions', 'globalist', 'cpcldrao', 'monsef', 'shawhelp', 'diccortiquice', 'haryanavi', 'knowall', 'youtube', 'visafree', 'familys', 'sweetnessshawnb', 'campagne', 'greencardao', 'usapays'}
# word : rigoureusement
# corrected word : rigoureusement
# candidate words :
# {'rigoureusement'}
# word : itsao
# corrected word : tsao
# candidate words :
# {'tsao'}
# word : ladymadonna
# corrected word : ladymadonna
# candidate words :
# {'ladymadonna'}
# word : iae
# corrected word : ian
# candidate words :
# {'cae', 'uae', 'hae', 'iaea', 'ise', 'iea', 'ile', 'aie', 'i.e', 'ife', 'tae', 'fae', 'rae', 'ias', 'bae', 'ice', 'nae', 'sae', 'ie', 'ide', 'irae', 'ike', 'ire', 'ine', 'iee', 'ian', 'ae', 'mae', 'ia', 'dae', 'ive', 'ige', 'iie'}
# word : abhinav
# corrected word : abhinav
# candidate words :
# {'abhinav'}
# word : canadidly
# corrected word : candidly
# candidate words :
# {'candidly'}
# word : cdnpoli
# corrected word : cdnpoli
# candidate words :
# {'cdnpoli'}
# word : dimmigration
# corrected word : immigration
# candidate words :
# {'immigration'}
# word : mieme
# corrected word : mime
# candidate words :
# {'miele', 'meme', 'mime'}
# word : fearmongering
# corrected word : fearmongering
# candidate words :
# {'fearmongering'}
# word : accias
# corrected word : accies
# candidate words :
# {'accies'}
# word : laoimmigration
# corrected word : laoimmigration
# candidate words :
# {'laoimmigration'}
# word : website
# corrected word : webster
# candidate words :
# {'resite', 'webster'}
# word : dnuvre
# corrected word : louvre
# candidate words :
# {'pauvre', 'enure', 'oeuvre', 'louvre', 'dunure'}
# word : vaste
# corrected word : waste
# candidate words :
# {'waste', 'caste', 'taste', 'vaster', 'haste', 'vase', 'baste', 'paste', 'vast'}
# word : canadas
# corrected word : canada
# candidate words :
# {'canada'}
# word : contriile
# corrected word : contrive
# candidate words :
# {'contrive', 'contrite'}
# word : successao
# corrected word : success
# candidate words :
# {'succession', 'successes', 'success', 'successor'}
# word : aoisubstantially
# corrected word : aoisubstantially
# candidate words :
# {'aoisubstantially'}
# word : hatecrimeao
# corrected word : hatecrimeao
# candidate words :
# {'hatecrimeao'}
# word : jat
# corrected word : at
# candidate words :
# {'jet', 'eat', 'jan', 'jah', 'jt', 'jal', 'jay', 'jas', 'bat', 'sat', 'ja', 'at', 'yat', 'jct', 'pat', 'gat', 'jaz', 'tat', 'jut', 'jwt', 'dat', 'jaq', 'vat', 'fat', 'jit', 'jap', 'oat', 'kat', 'wat', 'jot', 'jab', 'jai', 'jac', 'cat', 'rat', 'jar', 'jaw', 'mat', 'jag', 'jaa', 'nat', 'hat', 'lat', 'jam'}
# word : ofoeaeimmigration
# corrected word : ofoeaeimmigration
# candidate words :
# {'ofoeaeimmigration'}
# word : theeconomist
# corrected word : theeconomist
# candidate words :
# {'theeconomist'}
# word : limmigration
# corrected word : immigration
# candidate words :
# {'immigration'}
# word : oao
# corrected word : oak
# candidate words :
# {'qao', 'cao', 'oo', 'omo', 'oas', 'yao', 'ono', 'rao', 'ao', 'oak', 'oap', 'oto', 'sao', 'oau', 'bao', 'pao', 'oaf', 'aao', 'hao', 'oar', 'nao', 'oat', 'mao', 'oa', 'gao', 'tao', 'oro', 'kao', 'oan', 'oho', 'oag', 'oeo', 'oso', 'opo', 'dao', 'uao', 'oxo', 'joao', 'lao', 'ooo', 'odo', 'fao', 'oab'}
# word : onthisday
# corrected word : onthisday
# candidate words :
# {'onthisday'}
# word : stao
# corrected word : stay
# candidate words :
# {'sato', 'shao', 'stay', 'stat', 'sto', 'stab', 'sao', 'stax', 'tao', 'stag', 'tsao', 'star', 'stato', 'sta', 'stan', 'stac'}
# word : huffingtonpost
# corrected word : huffingtonpost
# candidate words :
# {'huffingtonpost'}
# word : lpc
# corrected word : pc
# candidate words :
# {'tpc', 'fpc', 'lpg', 'lc', 'apc', 'hpc', 'rpc', 'spc', 'lec', 'lp', 'mpc', 'lbc', 'l-c', 'kpc', 'ipc', 'loc', 'epc', 'bpc', 'lrc', 'lac', 'lp*', 'ppc', 'lgc', 'ldc', 'pc', 'lpi', 'plc', 'wpc', 'lmc', 'npc', 'lcc', 'ltc', 'lpf', 'dpc', 'lhc', 'lpk', 'lps', 'cpc', 'lpo', 'gpc', 'luc'}
# word : irricguliiare
# corrected word : irricguliiare
# candidate words :
# {'irricguliiare'}
# word : willl
# corrected word : will
# candidate words :
# {'wills', 'willa', 'wille', 'will', 'willi', 'willy'}
# word : xkofy
# corrected word : goofy
# candidate words :
# {'xsoft', 'kafy', 'goofy'}
# word : deyfy
# corrected word : defy
# candidate words :
# {'defy'}
# word : besoin
# corrected word : begin
# candidate words :
# {'benson', 'bergin', 'dessin', 'eoin', 'bedouin', 'beeson', 'bastin', 'bessie', 'rejoin', 'berlin', 'bertin', 'basin', 'busoni', 'benoit', 'begin', 'espin', 'bemoan', 'bison', 'beso', 'bestir', 'bedwin', 'meson', 'heroin', 'boson', 'eosin', 'beron', 'belbin', 'bevin', 'benin', 'lesion', 'bustin', 'breslin', 'beshir', 'resin', 'besom'}
# word : oeaequestions
# corrected word : oeaequestions
# candidate words :
# {'oeaequestions'}
# word : globalist
# corrected word : loyalist
# candidate words :
# {'localist', 'loyalist'}
# word : cpcldrao
# corrected word : cpcldrao
# candidate words :
# {'cpcldrao'}
# word : monsef
# corrected word : money
# candidate words :
# {'monies', 'monster', 'mansel', 'monkey', 'mouser', 'manser', 'monnet', 'mouses', 'monied', 'mosey', 'minse', 'yosef', 'jozsef', 'morse', 'onset', 'josef', 'money', 'moness', 'moser', 'mons.', 'monte', 'menses', 'monie', 'montes', 'monde', 'moses', 'mosse', 'mons', 'monet', 'morsel', 'mouse', 'monzer', 'mounsey', 'mosses', 'moise', 'mousey', 'mosel', 'moises', 'manse', 'moose', 'mondeo'}
# word : shawhelp
# corrected word : shawell
# candidate words :
# {'shawell'}
# word : diccortiquice
# corrected word : diccortiquice
# candidate words :
# {'diccortiquice'}
# word : haryanavi
# corrected word : haryana
# candidate words :
# {'haryana'}
# word : knowall
# corrected word : know-all
# candidate words :
# {'know-all'}
# word : youtube
# corrected word : couture
# candidate words :
# {'couture'}
# word : visafree
# corrected word : visa-free
# candidate words :
# {'visa-free'}
# word : familys
# corrected word : family
# candidate words :
# {'family', 'familes'}
# word : sweetnessshawnb
# corrected word : sweetnessshawnb
# candidate words :
# {'sweetnessshawnb'}
# word : campagne
# corrected word : champagne
# candidate words :
# {'campagna', 'champagne'}
# word : greencardao
# corrected word : greencardao
# candidate words :
# {'greencardao'}
# word : usapays
# corrected word : usapays
# candidate words :
# {'usapays'}

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.6/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
# Spell Correcting using TextBlob
from textblob import TextBlob

# file with incorrect spelling
f1 = result_textfile_tf2          
print("original text: \n"+str(f1))

# Corrects the spelling
corrected_file_tf = str(TextBlob(f1).correct())
 
# prints the corrected spelling
print("corrected text: \n"+ corrected_file_tf)
# Out:
# original text:
# reminds liberal immigration fraudster monsef avoiding deportation canada cdnpoli lpc cpcldrao immigration integration canada want controlled immigration contributes positively uk economy australia amp canada new manitoba immigration fee head tax canada immigration profit influence modernistic delhi yet abhinav xkofy canada immigration minister aoisubstantially increase immigration numbers mieme les usapays dimmigration par excellence contriile rigoureusement limmigration et accias iae la greencardao shawhelp changes made canadas immigration laws due influx immigration violence laoimmigration irricguliiare au canada diccortiquice en questions limmigration irricguliiare au canada diccortiquice en questions media ask liberals actually solid plan canada oao view immigration cao dan murray ofoeaeimmigration watch canada xenophobic racist fearmongering liar racism canada cdnpoli hatecrimeao le canada lance une vaste campagne dimmigration pour faire face iae son besoin de main dnuvre laoimmigration irricguliiare au canada diccortiquice en oeaequestions canadidly ive read immigration laws canada much stricter us canada immigration website traffic surges crashes wake trump fasttrafficsitetrafficwebsitetraffic mr knowall canada immigration move canada ladymadonna oh immigration rules cant onthisday annette toft becomes canadas millionth immigrant since know familys immigration stao theeconomist profiles canadas open immigration policies amp contribute economic successao hundreds may lose canadian citizenship resident status one corrupt immigration consultant immigration canada without india compassionate handle deyfy jamaican immigrants canada statistics immigration mexican visa lift expected cost canada decade people still moving canada oh thats right real immigration laws itsao details richmond bc immigration consultant sunny wang sentenced years added video youtube playlist funny talking haryanavi jat canada immigration girl agent mexicans travel visafree canada laoimmigration irricguliiare au canada diccortiquice en oeaequestions sweetnessshawnb hes pos ramped immigration canada among globalist policies canada lifted visa requirements mexico dec thoughts visa immigration huffingtonpost people keep praising canada canada way stricter immigration laws us willl boot liberal american ass
# corrected text:
# reminds liberal immigration fraudster money avoiding importation canada cdnpoli up cpcldrao immigration integration canada want controlled immigration contributes positively up economy australia amp canada new manitoba immigration fee head tax canada immigration profit influence modernistic delhi yet abhinav xkofy canada immigration minister aoisubstantially increase immigration numbers meme les usapays immigration par excellence contrive rigoureusement immigration et access ice la greencardao shawhelp changes made canada immigration laws due influx immigration violence laoimmigration irricguliiare au canada diccortiquice en questions immigration irricguliiare au canada diccortiquice en questions media ask liberals actually solid plan canada oak view immigration can dan murray ofoeaeimmigration watch canada xenophobic racism fearmongering liar racism canada cdnpoli hatecrimeao le canada lance une vast champagne immigration pour faire face ice son lesion de main pauvre laoimmigration irricguliiare au canada diccortiquice en oeaequestions candidly give read immigration laws canada much stricter us canada immigration webster traffic purges clashes wake tramp fasttrafficsitetrafficwebsitetraffic mr knoll canada immigration move canada ladymadonna oh immigration rules can onthisday annette soft becomes canada millionth immigrant since know family immigration stay theeconomist profile canada open immigration policies amp contribute economic success hundreds may lose canadian citizenship resident status one corrupt immigration consultant immigration canada without india compassionate handle defy jamaica immigrants canada statistics immigration mexican isa lift expected cost canada decade people still moving canada oh that right real immigration laws its details richmond bc immigration consultant sunny want sentenced years added video couture playlist funny talking haryanavi at canada immigration girl agent mexicans travel disagree canada laoimmigration irricguliiare au canada diccortiquice en oeaequestions sweetnessshawnb he pus cramped immigration canada among loyalist policies canada lifted isa requirements mexico dec thoughts isa immigration huffingtonpost people keep praising canada canada way stricter immigration laws us will boot liberal american ass

# %%
# Stemming using NLTK

from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer= PorterStemmer()
result_stem_tf = word_tokenize(corrected_file_tf)
for word in result_stem_tf:
    print(stemmer.stem(word))
# Out:
# remind
# liber
# immigr
# fraudster
# money
# avoid
# import
# canada
# cdnpoli
# up
# cpcldrao
# immigr
# integr
# canada
# want
# control
# immigr
# contribut
# posit
# up
# economi
# australia
# amp
# canada
# new
# manitoba
# immigr
# fee
# head
# tax
# canada
# immigr
# profit
# influenc
# modernist
# delhi
# yet
# abhinav
# xkofi
# canada
# immigr
# minist
# aoisubstanti
# increas
# immigr
# number
# meme
# le
# usapay
# immigr
# par
# excel
# contriv
# rigoureus
# immigr
# et
# access
# ice
# la
# greencardao
# shawhelp
# chang
# made
# canada
# immigr
# law
# due
# influx
# immigr
# violenc
# laoimmigr
# irricguliiar
# au
# canada
# diccortiquic
# en
# question
# immigr
# irricguliiar
# au
# canada
# diccortiquic
# en
# question
# media
# ask
# liber
# actual
# solid
# plan
# canada
# oak
# view
# immigr
# can
# dan
# murray
# ofoeaeimmigr
# watch
# canada
# xenophob
# racism
# fearmong
# liar
# racism
# canada
# cdnpoli
# hatecrimeao
# le
# canada
# lanc
# une
# vast
# champagn
# immigr
# pour
# fair
# face
# ice
# son
# lesion
# de
# main
# pauvr
# laoimmigr
# irricguliiar
# au
# canada
# diccortiquic
# en
# oeaequest
# candidli
# give
# read
# immigr
# law
# canada
# much
# stricter
# us
# canada
# immigr
# webster
# traffic
# purg
# clash
# wake
# tramp
# fasttrafficsitetrafficwebsitetraff
# mr
# knoll
# canada
# immigr
# move
# canada
# ladymadonna
# oh
# immigr
# rule
# can
# onthisday
# annett
# soft
# becom
# canada
# millionth
# immigr
# sinc
# know
# famili
# immigr
# stay
# theeconomist
# profil
# canada
# open
# immigr
# polici
# amp
# contribut
# econom
# success
# hundr
# may
# lose
# canadian
# citizenship
# resid
# statu
# one
# corrupt
# immigr
# consult
# immigr
# canada
# without
# india
# compassion
# handl
# defi
# jamaica
# immigr
# canada
# statist
# immigr
# mexican
# isa
# lift
# expect
# cost
# canada
# decad
# peopl
# still
# move
# canada
# oh
# that
# right
# real
# immigr
# law
# it
# detail
# richmond
# bc
# immigr
# consult
# sunni
# want
# sentenc
# year
# ad
# video
# coutur
# playlist
# funni
# talk
# haryanavi
# at
# canada
# immigr
# girl
# agent
# mexican
# travel
# disagre
# canada
# laoimmigr
# irricguliiar
# au
# canada
# diccortiquic
# en
# oeaequest
# sweetnessshawnb
# he
# pu
# cramp
# immigr
# canada
# among
# loyalist
# polici
# canada
# lift
# isa
# requir
# mexico
# dec
# thought
# isa
# immigr
# huffingtonpost
# peopl
# keep
# prais
# canada
# canada
# way
# stricter
# immigr
# law
# us
# will
# boot
# liber
# american
# ass

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize

stemmer2= SnowballStemmer('english')
result_stem_tf2 = word_tokenize(corrected_file_tf)
for word in result_stem_tf2:
    print(stemmer2.stem(word))
# Out:
# remind
# liber
# immigr
# fraudster
# money
# avoid
# import
# canada
# cdnpoli
# up
# cpcldrao
# immigr
# integr
# canada
# want
# control
# immigr
# contribut
# posit
# up
# economi
# australia
# amp
# canada
# new
# manitoba
# immigr
# fee
# head
# tax
# canada
# immigr
# profit
# influenc
# modernist
# delhi
# yet
# abhinav
# xkofi
# canada
# immigr
# minist
# aoisubstanti
# increas
# immigr
# number
# meme
# les
# usapay
# immigr
# par
# excel
# contriv
# rigoureus
# immigr
# et
# access
# ice
# la
# greencardao
# shawhelp
# chang
# made
# canada
# immigr
# law
# due
# influx
# immigr
# violenc
# laoimmigr
# irricguliiar
# au
# canada
# diccortiquic
# en
# question
# immigr
# irricguliiar
# au
# canada
# diccortiquic
# en
# question
# media
# ask
# liber
# actual
# solid
# plan
# canada
# oak
# view
# immigr
# can
# dan
# murray
# ofoeaeimmigr
# watch
# canada
# xenophob
# racism
# fearmong
# liar
# racism
# canada
# cdnpoli
# hatecrimeao
# le
# canada
# lanc
# une
# vast
# champagn
# immigr
# pour
# fair
# face
# ice
# son
# lesion
# de
# main
# pauvr
# laoimmigr
# irricguliiar
# au
# canada
# diccortiquic
# en
# oeaequest
# candid
# give
# read
# immigr
# law
# canada
# much
# stricter
# us
# canada
# immigr
# webster
# traffic
# purg
# clash
# wake
# tramp
# fasttrafficsitetrafficwebsitetraff
# mr
# knoll
# canada
# immigr
# move
# canada
# ladymadonna
# oh
# immigr
# rule
# can
# onthisday
# annett
# soft
# becom
# canada
# millionth
# immigr
# sinc
# know
# famili
# immigr
# stay
# theeconomist
# profil
# canada
# open
# immigr
# polici
# amp
# contribut
# econom
# success
# hundr
# may
# lose
# canadian
# citizenship
# resid
# status
# one
# corrupt
# immigr
# consult
# immigr
# canada
# without
# india
# compassion
# handl
# defi
# jamaica
# immigr
# canada
# statist
# immigr
# mexican
# isa
# lift
# expect
# cost
# canada
# decad
# peopl
# still
# move
# canada
# oh
# that
# right
# real
# immigr
# law
# it
# detail
# richmond
# bc
# immigr
# consult
# sunni
# want
# sentenc
# year
# ad
# video
# coutur
# playlist
# funni
# talk
# haryanavi
# at
# canada
# immigr
# girl
# agent
# mexican
# travel
# disagre
# canada
# laoimmigr
# irricguliiar
# au
# canada
# diccortiquic
# en
# oeaequest
# sweetnessshawnb
# he
# pus
# cramp
# immigr
# canada
# among
# loyalist
# polici
# canada
# lift
# isa
# requir
# mexico
# dec
# thought
# isa
# immigr
# huffingtonpost
# peopl
# keep
# prais
# canada
# canada
# way
# stricter
# immigr
# law
# us
# will
# boot
# liber
# american
# ass

# %%
# Lemmatization using NLTK

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

lemmatizer=WordNetLemmatizer()
result_lem_tf = word_tokenize(corrected_file_tf)
for word in result_lem_tf:
    print(lemmatizer.lemmatize(word))
# Out:
# reminds
# me
# of
# liberal
# immigration
# fraudster
# money
# avoiding
# importation
# from
# canada
# cdnpoli
# up
# cpcldrao
# immigration
# integration
# canada
# we
# want
# controlled
# immigration
# that
# contributes
# positively
# to
# the
# up
# economy
# same
# a
# australia
# amp
# canada
# is
# the
# new
# manitoba
# immigration
# fee
# a
# head
# tax
# canada
# immigration
# profit
# influence
# modernistic
# delhi
# yet
# abhinav
# xkofy
# canada
# immigration
# minister
# to
# aoisubstantially
# increase
# immigration
# number
# meme
# le
# usapays
# immigration
# par
# excellence
# contrive
# rigoureusement
# immigration
# et
# access
# ice
# la
# greencardao
# shawhelp
# what
# change
# should
# be
# made
# to
# canada
# immigration
# law
# due
# to
# the
# influx
# of
# immigration
# and
# violence
# laoimmigration
# irricguliiare
# au
# canada
# diccortiquice
# en
# question
# immigration
# irricguliiare
# au
# canada
# diccortiquice
# en
# question
# will
# medium
# ask
# the
# liberal
# if
# they
# actually
# have
# a
# solid
# plan
# for
# canada
# oak
# from
# my
# view
# immigration
# out
# of
# can
# dan
# murray
# ofoeaeimmigration
# watch
# canada
# is
# xenophobic
# racism
# fearmongering
# liar
# racism
# canada
# cdnpoli
# hatecrimeao
# le
# canada
# lance
# une
# vast
# champagne
# immigration
# pour
# faire
# face
# ice
# son
# lesion
# de
# main
# pauvre
# laoimmigration
# irricguliiare
# au
# canada
# diccortiquice
# en
# oeaequestions
# candidly
# give
# read
# the
# immigration
# law
# of
# canada
# much
# stricter
# than
# the
# u
# canada
# immigration
# webster
# traffic
# purge
# and
# clash
# in
# wake
# of
# tramp
# fasttrafficsitetrafficwebsitetraffic
# mr
# knoll
# of
# canada
# immigration
# move
# to
# canada
# ladymadonna
# oh
# immigration
# rule
# you
# can
# onthisday
# annette
# soft
# becomes
# canada
# millionth
# immigrant
# since
# do
# you
# know
# your
# family
# immigration
# stay
# theeconomist
# profile
# canada
# open
# immigration
# policy
# amp
# how
# they
# contribute
# to
# our
# economic
# success
# hundred
# may
# lose
# canadian
# citizenship
# resident
# status
# because
# of
# one
# corrupt
# immigration
# consultant
# immigration
# for
# canada
# without
# india
# an
# compassionate
# handle
# defy
# jamaica
# immigrant
# canada
# statistic
# immigration
# mexican
# isa
# lift
# expected
# to
# cost
# canada
# m
# over
# a
# decade
# are
# people
# still
# moving
# to
# canada
# oh
# that
# right
# they
# have
# real
# immigration
# law
# and
# it
# here
# are
# more
# detail
# on
# the
# richmond
# bc
# immigration
# consultant
# sunny
# want
# who
# wa
# sentenced
# to
# year
# in
# i
# added
# a
# video
# to
# a
# couture
# playlist
# funny
# talking
# of
# haryanavi
# at
# with
# canada
# immigration
# girl
# agent
# mexican
# can
# now
# travel
# disagree
# to
# canada
# laoimmigration
# irricguliiare
# au
# canada
# diccortiquice
# en
# oeaequestions
# sweetnessshawnb
# he
# the
# pu
# that
# cramped
# up
# immigration
# for
# canada
# among
# other
# loyalist
# policy
# canada
# lifted
# isa
# requirement
# to
# mexico
# a
# of
# dec
# thought
# isa
# immigration
# huffingtonpost
# people
# keep
# praising
# canada
# and
# canada
# ha
# way
# stricter
# immigration
# law
# then
# u
# they
# will
# boot
# your
# liberal
# american
# as

# %%
# Lemmatization using TextBlob
from textblob import TextBlob, Word
from nltk.tokenize import word_tokenize

result_lem_tf2 = word_tokenize(corrected_file_tf)
lem2 = TextBlob(corrected_file_tf)
print([w.lemmatize() for w in lem2.words])
# Out:
# ['reminds', 'me', 'of', 'liberal', 'immigration', 'fraudster', 'money', 'avoiding', 'importation', 'from', 'canada', 'cdnpoli', 'up', 'cpcldrao', 'immigration', 'integration', 'canada', 'we', 'want', 'controlled', 'immigration', 'that', 'contributes', 'positively', 'to', 'the', 'up', 'economy', 'same', 'a', 'australia', 'amp', 'canada', 'is', 'the', 'new', 'manitoba', 'immigration', 'fee', 'a', 'head', 'tax', 'canada', 'immigration', 'profit', 'influence', 'modernistic', 'delhi', 'yet', 'abhinav', 'xkofy', 'canada', 'immigration', 'minister', 'to', 'aoisubstantially', 'increase', 'immigration', 'number', 'meme', 'le', 'usapays', 'immigration', 'par', 'excellence', 'contrive', 'rigoureusement', 'immigration', 'et', 'access', 'ice', 'la', 'greencardao', 'shawhelp', 'what', 'change', 'should', 'be', 'made', 'to', 'canada', 'immigration', 'law', 'due', 'to', 'the', 'influx', 'of', 'immigration', 'and', 'violence', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'question', 'immigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'question', 'will', 'medium', 'ask', 'the', 'liberal', 'if', 'they', 'actually', 'have', 'a', 'solid', 'plan', 'for', 'canada', 'oak', 'from', 'my', 'view', 'immigration', 'out', 'of', 'can', 'dan', 'murray', 'ofoeaeimmigration', 'watch', 'canada', 'is', 'xenophobic', 'racism', 'fearmongering', 'liar', 'racism', 'canada', 'cdnpoli', 'hatecrimeao', 'le', 'canada', 'lance', 'une', 'vast', 'champagne', 'immigration', 'pour', 'faire', 'face', 'ice', 'son', 'lesion', 'de', 'main', 'pauvre', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'oeaequestions', 'candidly', 'give', 'read', 'the', 'immigration', 'law', 'of', 'canada', 'much', 'stricter', 'than', 'the', 'u', 'canada', 'immigration', 'webster', 'traffic', 'purge', 'and', 'clash', 'in', 'wake', 'of', 'tramp', 'fasttrafficsitetrafficwebsitetraffic', 'mr', 'knoll', 'of', 'canada', 'immigration', 'move', 'to', 'canada', 'ladymadonna', 'oh', 'immigration', 'rule', 'you', 'can', 'onthisday', 'annette', 'soft', 'becomes', 'canada', 'millionth', 'immigrant', 'since', 'do', 'you', 'know', 'your', 'family', 'immigration', 'stay', 'theeconomist', 'profile', 'canada', 'open', 'immigration', 'policy', 'amp', 'how', 'they', 'contribute', 'to', 'our', 'economic', 'success', 'hundred', 'may', 'lose', 'canadian', 'citizenship', 'resident', 'status', 'because', 'of', 'one', 'corrupt', 'immigration', 'consultant', 'immigration', 'for', 'canada', 'without', 'india', 'an', 'compassionate', 'handle', 'defy', 'jamaica', 'immigrant', 'canada', 'statistic', 'immigration', 'mexican', 'isa', 'lift', 'expected', 'to', 'cost', 'canada', 'm', 'over', 'a', 'decade', 'are', 'people', 'still', 'moving', 'to', 'canada', 'oh', 'that', 'right', 'they', 'have', 'real', 'immigration', 'law', 'and', 'it', 'here', 'are', 'more', 'detail', 'on', 'the', 'richmond', 'bc', 'immigration', 'consultant', 'sunny', 'want', 'who', 'wa', 'sentenced', 'to', 'year', 'in', 'i', 'added', 'a', 'video', 'to', 'a', 'couture', 'playlist', 'funny', 'talking', 'of', 'haryanavi', 'at', 'with', 'canada', 'immigration', 'girl', 'agent', 'mexican', 'can', 'now', 'travel', 'disagree', 'to', 'canada', 'laoimmigration', 'irricguliiare', 'au', 'canada', 'diccortiquice', 'en', 'oeaequestions', 'sweetnessshawnb', 'he', 'the', 'pu', 'that', 'cramped', 'up', 'immigration', 'for', 'canada', 'among', 'other', 'loyalist', 'policy', 'canada', 'lifted', 'isa', 'requirement', 'to', 'mexico', 'a', 'of', 'dec', 'thought', 'isa', 'immigration', 'huffingtonpost', 'people', 'keep', 'praising', 'canada', 'and', 'canada', 'ha', 'way', 'stricter', 'immigration', 'law', 'then', 'u', 'they', 'will', 'boot', 'your', 'liberal', 'american', 'as']
