# %% [markdown]
# **Assignment1 - Information Retrieval**

# %% [markdown]
# **209381P - T.P.N. Silva**

# %% [markdown]
# **Preprocess Student Course Feedback**

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords

import pandas as pd
import numpy as np
 # Regular expressions
import re  
import string
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
# load text file
filename = '/content/drive/My Drive/Python/IR/student_course_feedback.txt'
file = open(filename, 'rt')
text = file.read()
file.close()

# text file before preprocessing
print(text)
print('=====================================================================================================================================\n')

# convert to lower case
text = text.lower()

# remove all html tags including <br /> tag
clean = re.compile('<.*?>')
text = re.sub(clean, '', text)

# remove unicode decimal digit
text = re.sub('\d+', '', text)

# remove leading and ending whitespace
text = text.strip()

# remove punctuation
text_output = text.translate(str.maketrans('', '', string.punctuation))

# split text by white space
text_output = text_output.split()

# text file after preprocessing
print(text_output)

result_textfile = (' '.join(str(word) for word in text_output))
print(result_textfile)
# Out:
# Honestly last seven lectures are good. Lectures are understandable. Lecture slides are very useful to self-study also. The given opportunity to ask questions from the lecturer is appreciative.
# "Good :)
# <br />please do recap at class starting it&#039;s better for us.
# <br />sometimes teaching speed is very high.
# <br />
# <br />Thanks ! :)
# <br /> "
# The lectures are good..but a bit speed.A in class working activity is a must one.So please take another hour in thursdays madame.
# "
# <br />We can hear your voice clearly and can understand the things you teach. Presentation slides also good source to refer . lf you can do more example questions within the classroom and it will help us to understand the principles well.
# <br />"
# Lectures was well structured and well organized. It was easy to understand. Lecture slides and labs were also well organized.
# Lectures were good. understandable.
# The lecture slides were well organized and the examples done in the class helped a lot to learn this new language and also the principles of OOP. Motivated to well. Would have been better if we discussed more about the solutions of coding exercisers.
# I think i learned a lot from the codes you write in the board. When i compare my codes with yours i can learn about my mistakes and good coding practices that i should follow. There fore i think it would be great if we can discuss more examples in the class.
# madam explained  the oop concepts clearly with examples.lectures were interesting.we want more scenario examples and answers with explanations in future.
# I satisfy about first 7 lectures. That way of teaching is really good for coming lectures too.
# lectuers are very good. take good effort to make undersatand every student in the room. very helpfull.
# I was able to obtain a clear picture about OOP and its concepts.
# "lecture slides, explanations were very clear.
# <br />it&#039;s very good to letting ask questions and explain again with suitable examples.
# <br />sometimes, some codes on white board were unclear at the back.
# <br />overall very good!!!
# <br />"
# The lectures were good and clear. And they weren&#039;t too fast. Writing code was somewhat confusing because I didn&#039;t know java before.
# Actually teaching is very good and can understand easily the concepts by examples which are given in the class.it will be more helpful if provide solved questions as well!. thankyou
# =====================================================================================================================================
#
# ['honestly', 'last', 'seven', 'lectures', 'are', 'good', 'lectures', 'are', 'understandable', 'lecture', 'slides', 'are', 'very', 'useful', 'to', 'selfstudy', 'also', 'the', 'given', 'opportunity', 'to', 'ask', 'questions', 'from', 'the', 'lecturer', 'is', 'appreciative', 'good', 'please', 'do', 'recap', 'at', 'class', 'starting', 'its', 'better', 'for', 'us', 'sometimes', 'teaching', 'speed', 'is', 'very', 'high', 'thanks', 'the', 'lectures', 'are', 'goodbut', 'a', 'bit', 'speeda', 'in', 'class', 'working', 'activity', 'is', 'a', 'must', 'oneso', 'please', 'take', 'another', 'hour', 'in', 'thursdays', 'madame', 'we', 'can', 'hear', 'your', 'voice', 'clearly', 'and', 'can', 'understand', 'the', 'things', 'you', 'teach', 'presentation', 'slides', 'also', 'good', 'source', 'to', 'refer', 'lf', 'you', 'can', 'do', 'more', 'example', 'questions', 'within', 'the', 'classroom', 'and', 'it', 'will', 'help', 'us', 'to', 'understand', 'the', 'principles', 'well', 'lectures', 'was', 'well', 'structured', 'and', 'well', 'organized', 'it', 'was', 'easy', 'to', 'understand', 'lecture', 'slides', 'and', 'labs', 'were', 'also', 'well', 'organized', 'lectures', 'were', 'good', 'understandable', 'the', 'lecture', 'slides', 'were', 'well', 'organized', 'and', 'the', 'examples', 'done', 'in', 'the', 'class', 'helped', 'a', 'lot', 'to', 'learn', 'this', 'new', 'language', 'and', 'also', 'the', 'principles', 'of', 'oop', 'motivated', 'to', 'well', 'would', 'have', 'been', 'better', 'if', 'we', 'discussed', 'more', 'about', 'the', 'solutions', 'of', 'coding', 'exercisers', 'i', 'think', 'i', 'learned', 'a', 'lot', 'from', 'the', 'codes', 'you', 'write', 'in', 'the', 'board', 'when', 'i', 'compare', 'my', 'codes', 'with', 'yours', 'i', 'can', 'learn', 'about', 'my', 'mistakes', 'and', 'good', 'coding', 'practices', 'that', 'i', 'should', 'follow', 'there', 'fore', 'i', 'think', 'it', 'would', 'be', 'great', 'if', 'we', 'can', 'discuss', 'more', 'examples', 'in', 'the', 'class', 'madam', 'explained', 'the', 'oop', 'concepts', 'clearly', 'with', 'exampleslectures', 'were', 'interestingwe', 'want', 'more', 'scenario', 'examples', 'and', 'answers', 'with', 'explanations', 'in', 'future', 'i', 'satisfy', 'about', 'first', 'lectures', 'that', 'way', 'of', 'teaching', 'is', 'really', 'good', 'for', 'coming', 'lectures', 'too', 'lectuers', 'are', 'very', 'good', 'take', 'good', 'effort', 'to', 'make', 'undersatand', 'every', 'student', 'in', 'the', 'room', 'very', 'helpfull', 'i', 'was', 'able', 'to', 'obtain', 'a', 'clear', 'picture', 'about', 'oop', 'and', 'its', 'concepts', 'lecture', 'slides', 'explanations', 'were', 'very', 'clear', 'its', 'very', 'good', 'to', 'letting', 'ask', 'questions', 'and', 'explain', 'again', 'with', 'suitable', 'examples', 'sometimes', 'some', 'codes', 'on', 'white', 'board', 'were', 'unclear', 'at', 'the', 'back', 'overall', 'very', 'good', 'the', 'lectures', 'were', 'good', 'and', 'clear', 'and', 'they', 'werent', 'too', 'fast', 'writing', 'code', 'was', 'somewhat', 'confusing', 'because', 'i', 'didnt', 'know', 'java', 'before', 'actually', 'teaching', 'is', 'very', 'good', 'and', 'can', 'understand', 'easily', 'the', 'concepts', 'by', 'examples', 'which', 'are', 'given', 'in', 'the', 'classit', 'will', 'be', 'more', 'helpful', 'if', 'provide', 'solved', 'questions', 'as', 'well', 'thankyou']
# honestly last seven lectures are good lectures are understandable lecture slides are very useful to selfstudy also the given opportunity to ask questions from the lecturer is appreciative good please do recap at class starting its better for us sometimes teaching speed is very high thanks the lectures are goodbut a bit speeda in class working activity is a must oneso please take another hour in thursdays madame we can hear your voice clearly and can understand the things you teach presentation slides also good source to refer lf you can do more example questions within the classroom and it will help us to understand the principles well lectures was well structured and well organized it was easy to understand lecture slides and labs were also well organized lectures were good understandable the lecture slides were well organized and the examples done in the class helped a lot to learn this new language and also the principles of oop motivated to well would have been better if we discussed more about the solutions of coding exercisers i think i learned a lot from the codes you write in the board when i compare my codes with yours i can learn about my mistakes and good coding practices that i should follow there fore i think it would be great if we can discuss more examples in the class madam explained the oop concepts clearly with exampleslectures were interestingwe want more scenario examples and answers with explanations in future i satisfy about first lectures that way of teaching is really good for coming lectures too lectuers are very good take good effort to make undersatand every student in the room very helpfull i was able to obtain a clear picture about oop and its concepts lecture slides explanations were very clear its very good to letting ask questions and explain again with suitable examples sometimes some codes on white board were unclear at the back overall very good the lectures were good and clear and they werent too fast writing code was somewhat confusing because i didnt know java before actually teaching is very good and can understand easily the concepts by examples which are given in the classit will be more helpful if provide solved questions as well thankyou

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
tokens = word_tokenize(result_textfile)
result = [i for i in tokens if not i in stop_words]
#Array form
print (result)
#String form
result_textfile2 = (' '.join(str(token) for token in result))
# Result text file after removing stop words
print(result_textfile2)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['honestly', 'last', 'seven', 'lectures', 'good', 'lectures', 'understandable', 'lecture', 'slides', 'useful', 'selfstudy', 'also', 'given', 'opportunity', 'ask', 'questions', 'lecturer', 'appreciative', 'good', 'please', 'recap', 'class', 'starting', 'better', 'us', 'sometimes', 'teaching', 'speed', 'high', 'thanks', 'lectures', 'goodbut', 'bit', 'speeda', 'class', 'working', 'activity', 'must', 'oneso', 'please', 'take', 'another', 'hour', 'thursdays', 'madame', 'hear', 'voice', 'clearly', 'understand', 'things', 'teach', 'presentation', 'slides', 'also', 'good', 'source', 'refer', 'lf', 'example', 'questions', 'within', 'classroom', 'help', 'us', 'understand', 'principles', 'well', 'lectures', 'well', 'structured', 'well', 'organized', 'easy', 'understand', 'lecture', 'slides', 'labs', 'also', 'well', 'organized', 'lectures', 'good', 'understandable', 'lecture', 'slides', 'well', 'organized', 'examples', 'done', 'class', 'helped', 'lot', 'learn', 'new', 'language', 'also', 'principles', 'oop', 'motivated', 'well', 'would', 'better', 'discussed', 'solutions', 'coding', 'exercisers', 'think', 'learned', 'lot', 'codes', 'write', 'board', 'compare', 'codes', 'learn', 'mistakes', 'good', 'coding', 'practices', 'follow', 'fore', 'think', 'would', 'great', 'discuss', 'examples', 'class', 'madam', 'explained', 'oop', 'concepts', 'clearly', 'exampleslectures', 'interestingwe', 'want', 'scenario', 'examples', 'answers', 'explanations', 'future', 'satisfy', 'first', 'lectures', 'way', 'teaching', 'really', 'good', 'coming', 'lectures', 'lectuers', 'good', 'take', 'good', 'effort', 'make', 'undersatand', 'every', 'student', 'room', 'helpfull', 'able', 'obtain', 'clear', 'picture', 'oop', 'concepts', 'lecture', 'slides', 'explanations', 'clear', 'good', 'letting', 'ask', 'questions', 'explain', 'suitable', 'examples', 'sometimes', 'codes', 'white', 'board', 'unclear', 'back', 'overall', 'good', 'lectures', 'good', 'clear', 'werent', 'fast', 'writing', 'code', 'somewhat', 'confusing', 'didnt', 'know', 'java', 'actually', 'teaching', 'good', 'understand', 'easily', 'concepts', 'examples', 'given', 'classit', 'helpful', 'provide', 'solved', 'questions', 'well', 'thankyou']
# honestly last seven lectures good lectures understandable lecture slides useful selfstudy also given opportunity ask questions lecturer appreciative good please recap class starting better us sometimes teaching speed high thanks lectures goodbut bit speeda class working activity must oneso please take another hour thursdays madame hear voice clearly understand things teach presentation slides also good source refer lf example questions within classroom help us understand principles well lectures well structured well organized easy understand lecture slides labs also well organized lectures good understandable lecture slides well organized examples done class helped lot learn new language also principles oop motivated well would better discussed solutions coding exercisers think learned lot codes write board compare codes learn mistakes good coding practices follow fore think would great discuss examples class madam explained oop concepts clearly exampleslectures interestingwe want scenario examples answers explanations future satisfy first lectures way teaching really good coming lectures lectuers good take good effort make undersatand every student room helpfull able obtain clear picture oop concepts lecture slides explanations clear good letting ask questions explain suitable examples sometimes codes white board unclear back overall good lectures good clear werent fast writing code somewhat confusing didnt know java actually teaching good understand easily concepts examples given classit helpful provide solved questions well thankyou

# %%
pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading https://files.pythonhosted.org/packages/f1/96/827c132397d0eb5731c1eda05dbfb019ede064ca8c7d0f329160ce0a4acd/pyspellchecker-0.5.5-py2.py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 9.5MB/s
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.5.5

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

# find those words that may be misspelled
misspelled_text = spell.unknown(result)
print("Mispelled count: {}".format(len(misspelled_text)))
print(misspelled_text)

for word in misspelled_text:
    corrected_word = spell.correction(word)
    candidate_words = spell.candidates(word)
    

    # Get the one `most likely` answer
    print('word :' + ' ' + word + '\n' + 'corrected word : ' + corrected_word)
  
    # Get a list of `likely` options
    print('candidate words :')
    print(candidate_words)
# Out:
# Mispelled count: 13
# {'didnt', 'oneso', 'goodbut', 'exercisers', 'classit', 'interestingwe', 'speeda', 'werent', 'lectuers', 'selfstudy', 'undersatand', 'exampleslectures', 'helpfull'}
# word : didnt
# corrected word : dint
# candidate words :
# {'dint', "didn't", 'didna', 'didn', 'didst'}
# word : oneso
# corrected word : ones
# candidate words :
# {'ones'}
# word : goodbut
# corrected word : goodbye
# candidate words :
# {'goodbye', "good'un", 'goodlet', 'woodcut'}
# word : exercisers
# corrected word : exercises
# candidate words :
# {'exercises'}
# word : classit
# corrected word : classic
# candidate words :
# {'classic'}
# word : interestingwe
# corrected word : interesting
# candidate words :
# {'interesting', 'interestingly'}
# word : speeda
# corrected word : speed
# candidate words :
# {'speedo', 'speedy', 'speeds', 'speed'}
# word : werent
# corrected word : were
# candidate words :
# {'newent', 'beren', 'went', 'dement', 'brent', 'erens', 'repent', 'verena', 'merest', 'keren', 'beret', 'sereno', 'resent', 'derwent', 'ferment', 'were', 'serpent', 'ferenc', 'cement', 'whereat', 'trent', 'percent', 'wren', 'rent', 'fervent', 'erect', 'weeny', 'relent', 'serena', 'parent', 'event', 'recent', 'wert', 'legent', 'wrest', 'decent', 'werner', 'wrens', 'serene', 'regent', 'bereft'}
# word : lectuers
# corrected word : lectures
# candidate words :
# {'lectures', 'lecturers'}
# word : selfstudy
# corrected word : self-study
# candidate words :
# {'self-study'}
# word : undersatand
# corrected word : understand
# candidate words :
# {'understand'}
# word : exampleslectures
# corrected word : exampleslectures
# candidate words :
# {'exampleslectures'}
# word : helpfull
# corrected word : helpful
# candidate words :
# {'helpful', 'helpfully'}

# %%
# Spell Correcting using TextBlob
from textblob import TextBlob

# file with incorrect spelling
f1 = result_textfile2           
print("original text: \n"+str(f1))

# Corrects the spelling
corrected_file = str(TextBlob(f1).correct())
 
# prints the corrected spelling
print("corrected text: \n"+ corrected_file)
# Out:
# original text:
# honestly last seven lectures good lectures understandable lecture slides useful selfstudy also given opportunity ask questions lecturer appreciative good please recap class starting better us sometimes teaching speed high thanks lectures goodbut bit speeda class working activity must oneso please take another hour thursdays madame hear voice clearly understand things teach presentation slides also good source refer lf example questions within classroom help us understand principles well lectures well structured well organized easy understand lecture slides labs also well organized lectures good understandable lecture slides well organized examples done class helped lot learn new language also principles oop motivated well would better discussed solutions coding exercisers think learned lot codes write board compare codes learn mistakes good coding practices follow fore think would great discuss examples class madam explained oop concepts clearly exampleslectures interestingwe want scenario examples answers explanations future satisfy first lectures way teaching really good coming lectures lectuers good take good effort make undersatand every student room helpfull able obtain clear picture oop concepts lecture slides explanations clear good letting ask questions explain suitable examples sometimes codes white board unclear back overall good lectures good clear werent fast writing code somewhat confusing didnt know java actually teaching good understand easily concepts examples given classit helpful provide solved questions well thankyou
# corrected text:
# honestly last seven lectures good lectures understandable lecture sides useful selfstudy also given opportunity ask questions lecturer appreciative good please reap class starting better us sometimes teaching speed high thanks lectures goodby bit speed class working activity must ones please take another hour thursdays madame hear voice clearly understand things teach presentation sides also good source refer of example questions within classroom help us understand principles well lectures well structures well organized easy understand lecture sides laws also well organized lectures good understandable lecture sides well organized examples done class helped lot learn new language also principles top motivate well would better discussed solutions coming exercises think learned lot codes write board compare codes learn mistakes good coming practices follow fore think would great discuss examples class madam explained top concepts clearly exampleslectures interesting want scenario examples answers explanations future satisfy first lectures way teaching really good coming lectures lectures good take good effort make understand every student room helpful able obtain clear picture top concepts lecture sides explanations clear good letting ask questions explain suitable examples sometimes codes white board unclear back overall good lectures good clear weren fast writing code somewhat confusing didn know cava actually teaching good understand easily concepts examples given classic helpful provide solved questions well thankyou

# %%
# Stemming using NLTK

from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer= PorterStemmer()
result_stem = word_tokenize(corrected_file)
for word in result_stem:
    print(stemmer.stem(word))
# Out:
# honestli
# last
# seven
# lectur
# good
# lectur
# understand
# lectur
# side
# use
# selfstudi
# also
# given
# opportun
# ask
# question
# lectur
# appreci
# good
# pleas
# reap
# class
# start
# better
# us
# sometim
# teach
# speed
# high
# thank
# lectur
# goodbi
# bit
# speed
# class
# work
# activ
# must
# one
# pleas
# take
# anoth
# hour
# thursday
# madam
# hear
# voic
# clearli
# understand
# thing
# teach
# present
# side
# also
# good
# sourc
# refer
# of
# exampl
# question
# within
# classroom
# help
# us
# understand
# principl
# well
# lectur
# well
# structur
# well
# organ
# easi
# understand
# lectur
# side
# law
# also
# well
# organ
# lectur
# good
# understand
# lectur
# side
# well
# organ
# exampl
# done
# class
# help
# lot
# learn
# new
# languag
# also
# principl
# top
# motiv
# well
# would
# better
# discuss
# solut
# come
# exercis
# think
# learn
# lot
# code
# write
# board
# compar
# code
# learn
# mistak
# good
# come
# practic
# follow
# fore
# think
# would
# great
# discuss
# exampl
# class
# madam
# explain
# top
# concept
# clearli
# exampleslectur
# interest
# want
# scenario
# exampl
# answer
# explan
# futur
# satisfi
# first
# lectur
# way
# teach
# realli
# good
# come
# lectur
# lectur
# good
# take
# good
# effort
# make
# understand
# everi
# student
# room
# help
# abl
# obtain
# clear
# pictur
# top
# concept
# lectur
# side
# explan
# clear
# good
# let
# ask
# question
# explain
# suitabl
# exampl
# sometim
# code
# white
# board
# unclear
# back
# overal
# good
# lectur
# good
# clear
# weren
# fast
# write
# code
# somewhat
# confus
# didn
# know
# cava
# actual
# teach
# good
# understand
# easili
# concept
# exampl
# given
# classic
# help
# provid
# solv
# question
# well
# thankyou

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize

stemmer2= SnowballStemmer('english')
result_stem2 = word_tokenize(corrected_file)
for word in result_stem2:
    print(stemmer2.stem(word))
# Out:
# honest
# last
# seven
# lectur
# good
# lectur
# understand
# lectur
# side
# use
# selfstudi
# also
# given
# opportun
# ask
# question
# lectur
# appreci
# good
# pleas
# reap
# class
# start
# better
# us
# sometim
# teach
# speed
# high
# thank
# lectur
# goodbi
# bit
# speed
# class
# work
# activ
# must
# one
# pleas
# take
# anoth
# hour
# thursday
# madam
# hear
# voic
# clear
# understand
# thing
# teach
# present
# side
# also
# good
# sourc
# refer
# of
# exampl
# question
# within
# classroom
# help
# us
# understand
# principl
# well
# lectur
# well
# structur
# well
# organ
# easi
# understand
# lectur
# side
# law
# also
# well
# organ
# lectur
# good
# understand
# lectur
# side
# well
# organ
# exampl
# done
# class
# help
# lot
# learn
# new
# languag
# also
# principl
# top
# motiv
# well
# would
# better
# discuss
# solut
# come
# exercis
# think
# learn
# lot
# code
# write
# board
# compar
# code
# learn
# mistak
# good
# come
# practic
# follow
# fore
# think
# would
# great
# discuss
# exampl
# class
# madam
# explain
# top
# concept
# clear
# exampleslectur
# interest
# want
# scenario
# exampl
# answer
# explan
# futur
# satisfi
# first
# lectur
# way
# teach
# realli
# good
# come
# lectur
# lectur
# good
# take
# good
# effort
# make
# understand
# everi
# student
# room
# help
# abl
# obtain
# clear
# pictur
# top
# concept
# lectur
# side
# explan
# clear
# good
# let
# ask
# question
# explain
# suitabl
# exampl
# sometim
# code
# white
# board
# unclear
# back
# overal
# good
# lectur
# good
# clear
# weren
# fast
# write
# code
# somewhat
# confus
# didn
# know
# cava
# actual
# teach
# good
# understand
# easili
# concept
# exampl
# given
# classic
# help
# provid
# solv
# question
# well
# thankyou

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.6/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
# Lemmatization using NLTK

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

lemmatizer=WordNetLemmatizer()
result_lem = word_tokenize(corrected_file)
for word in result_lem:
    print(lemmatizer.lemmatize(word))
# Out:
# honestly
# last
# seven
# lecture
# good
# lecture
# understandable
# lecture
# side
# useful
# selfstudy
# also
# given
# opportunity
# ask
# question
# lecturer
# appreciative
# good
# please
# reap
# class
# starting
# better
# u
# sometimes
# teaching
# speed
# high
# thanks
# lecture
# goodby
# bit
# speed
# class
# working
# activity
# must
# one
# please
# take
# another
# hour
# thursday
# madame
# hear
# voice
# clearly
# understand
# thing
# teach
# presentation
# side
# also
# good
# source
# refer
# of
# example
# question
# within
# classroom
# help
# u
# understand
# principle
# well
# lecture
# well
# structure
# well
# organized
# easy
# understand
# lecture
# side
# law
# also
# well
# organized
# lecture
# good
# understandable
# lecture
# side
# well
# organized
# example
# done
# class
# helped
# lot
# learn
# new
# language
# also
# principle
# top
# motivate
# well
# would
# better
# discussed
# solution
# coming
# exercise
# think
# learned
# lot
# code
# write
# board
# compare
# code
# learn
# mistake
# good
# coming
# practice
# follow
# fore
# think
# would
# great
# discus
# example
# class
# madam
# explained
# top
# concept
# clearly
# exampleslectures
# interesting
# want
# scenario
# example
# answer
# explanation
# future
# satisfy
# first
# lecture
# way
# teaching
# really
# good
# coming
# lecture
# lecture
# good
# take
# good
# effort
# make
# understand
# every
# student
# room
# helpful
# able
# obtain
# clear
# picture
# top
# concept
# lecture
# side
# explanation
# clear
# good
# letting
# ask
# question
# explain
# suitable
# example
# sometimes
# code
# white
# board
# unclear
# back
# overall
# good
# lecture
# good
# clear
# weren
# fast
# writing
# code
# somewhat
# confusing
# didn
# know
# cava
# actually
# teaching
# good
# understand
# easily
# concept
# example
# given
# classic
# helpful
# provide
# solved
# question
# well
# thankyou

# %%
# Lemmatization using TextBlob
from textblob import TextBlob, Word
from nltk.tokenize import word_tokenize

result_lem = word_tokenize(corrected_file)
lem2 = TextBlob(corrected_file)
print([w.lemmatize() for w in lem2.words])
# Out:
# ['honestly', 'last', 'seven', 'lecture', 'good', 'lecture', 'understandable', 'lecture', 'side', 'useful', 'selfstudy', 'also', 'given', 'opportunity', 'ask', 'question', 'lecturer', 'appreciative', 'good', 'please', 'reap', 'class', 'starting', 'better', 'u', 'sometimes', 'teaching', 'speed', 'high', 'thanks', 'lecture', 'goodby', 'bit', 'speed', 'class', 'working', 'activity', 'must', 'one', 'please', 'take', 'another', 'hour', 'thursday', 'madame', 'hear', 'voice', 'clearly', 'understand', 'thing', 'teach', 'presentation', 'side', 'also', 'good', 'source', 'refer', 'of', 'example', 'question', 'within', 'classroom', 'help', 'u', 'understand', 'principle', 'well', 'lecture', 'well', 'structure', 'well', 'organized', 'easy', 'understand', 'lecture', 'side', 'law', 'also', 'well', 'organized', 'lecture', 'good', 'understandable', 'lecture', 'side', 'well', 'organized', 'example', 'done', 'class', 'helped', 'lot', 'learn', 'new', 'language', 'also', 'principle', 'top', 'motivate', 'well', 'would', 'better', 'discussed', 'solution', 'coming', 'exercise', 'think', 'learned', 'lot', 'code', 'write', 'board', 'compare', 'code', 'learn', 'mistake', 'good', 'coming', 'practice', 'follow', 'fore', 'think', 'would', 'great', 'discus', 'example', 'class', 'madam', 'explained', 'top', 'concept', 'clearly', 'exampleslectures', 'interesting', 'want', 'scenario', 'example', 'answer', 'explanation', 'future', 'satisfy', 'first', 'lecture', 'way', 'teaching', 'really', 'good', 'coming', 'lecture', 'lecture', 'good', 'take', 'good', 'effort', 'make', 'understand', 'every', 'student', 'room', 'helpful', 'able', 'obtain', 'clear', 'picture', 'top', 'concept', 'lecture', 'side', 'explanation', 'clear', 'good', 'letting', 'ask', 'question', 'explain', 'suitable', 'example', 'sometimes', 'code', 'white', 'board', 'unclear', 'back', 'overall', 'good', 'lecture', 'good', 'clear', 'weren', 'fast', 'writing', 'code', 'somewhat', 'confusing', 'didn', 'know', 'cava', 'actually', 'teaching', 'good', 'understand', 'easily', 'concept', 'example', 'given', 'classic', 'helpful', 'provide', 'solved', 'question', 'well', 'thankyou']
